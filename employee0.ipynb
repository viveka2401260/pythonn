# %%
class Employee:
    def __init__(self, name, emp_id):
        self._name = name        # protected member
        self._emp_id = emp_id    # protected member

    # Step 2: Base class methods
    def calculate_salary(self):
        print("Salary calculation not defined for base Employee class")

    def display_details(self):
        print(f"Employee Name : {self._name}")
        print(f"Employee ID   : {self._emp_id}")



class FullTimeEmployee(Employee):
    def __init__(self, name, emp_id, monthly_salary):
        super().__init__(name, emp_id)
        self.monthly_salary = monthly_salary

    def calculate_salary(self):
        return self.monthly_salary


class PartTimeEmployee(Employee):
    def __init__(self, name, emp_id, hours_worked, rate_per_hour):
        super().__init__(name, emp_id)
        self.hours_worked = hours_worked
        self.rate_per_hour = rate_per_hour

    def calculate_salary(self):
        return self.hours_worked * self.rate_per_hour



employees = [
    FullTimeEmployee("Amit", 101, 50000),
    PartTimeEmployee("Riya", 102, 80, 300)
]

for emp in employees:
    emp.display_details()
    print("Employee Type :", emp.__class__.__name__)
    print("Calculated Salary :", emp.calculate_salary())
    print("-" * 40)
# Out:
# Employee Name : Amit
# Employee ID   : 101
# Employee Type : FullTimeEmployee
# Calculated Salary : 50000
# ----------------------------------------
# Employee Name : Riya
# Employee ID   : 102
# Employee Type : PartTimeEmployee
# Calculated Salary : 24000
# ----------------------------------------
