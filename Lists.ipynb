# %%
list1=[1,2,"python","hello"]
list2=["amy","ryan","henry","emma"]

print(list1)
print(list2)
print(type(list1))
print(type(list2))
# Out:
# [1, 2, 'python', 'hello']
# ['amy', 'ryan', 'henry', 'emma']
# <class 'list'>
# <class 'list'>

# %%
a=["amy","opinion","arya",6,5]
b=["amy","opinion","arya",6,5]
a==b
# Out:
# True

# %%
list = [1,2,3,4,5,5,6]
print(list[0])
print(list[1])
print(list[2])
print(list[3])
print(list[0:6])
print(list[:])
print(list[2:5])
# Out:
# 1
# 2
# 3
# 4
# [1, 2, 3, 4, 5, 5]
# [1, 2, 3, 4, 5, 5, 6]
# [3, 4, 5]

# %%
list=[1,2,3,4,5]
print(list[-2])
print(list[:-1])
# Out:
# 4
# [1, 2, 3, 4]

# %%
list1=[1,2,33,45,60]
l =list1*3
print(l)
# Out:
# [1, 2, 33, 45, 60, 1, 2, 33, 45, 60, 1, 2, 33, 45, 60]

# %%
list1=[1,2,33,45,60]
list2=[1,9,22,45,60]
l=list1+list2
print(l)
# Out:
# [1, 2, 33, 45, 60, 1, 9, 22, 45, 60]

# %%
list1=[1,2,33,45,60]
list1=[1,2,33,45,60]
# Out:
# 1
# 2
# 33
# 45
# 60

# %%
list1=[100,200,303,450,600]
print(900 in list1)
print(450 in list1)
# Out:
# False
# True

# %%
list=["john","junghook","jimin"]
for i in list:
  print(i)
# Out:
# john
# junghook
# jimin

# %%
list = [0,1,2,3]
print("printing original list:")
for i in list:
  print(i,end=" ")
list.remove(2)
print("\nprinting the list after the removal of first element: ")
for i in list:
  print(i,end=" ")
# Out:
# printing original list:
# 0 1 2 3
# printing the list after the removal of first element:
# 0 1 3
